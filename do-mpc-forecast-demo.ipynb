# %% [markdown]
# # Demo of Using A Forecast with MPC

# %%
import numpy as np
import matplotlib.pyplot as plt
import casadi as cas
import do_mpc

# %% [markdown]
# ## Construct System Model
#
# ```none
#               ┌────────┐
#   F_in_1 ────►┤  Tank  │
#   F_in_2 ────►┤        │
#               │        ├─────► F_out
#               └────────┘
# ```
#
# States
#  1. Tank level
#  2. Tank mass
#
# Inputs:
#  1. Feed 1 inflow rate
#  2. Feed 2 inflow rate
#  3. Feed 1 inflow concentration
#  4. Feed 2 inflow concentration
#  5. Tank outflow rate
#
# Outputs:
#  1. Tank level
#  2. Tank mass
#  3. Tank outflow concentration

# %%
# Construct mixing tank model
model_type = "continuous"
model = do_mpc.model.Model(model_type)

# Level (m)
L = model.set_variable(var_type="_x", var_name="L", shape=(1, 1))

# Mass of mineral (tons)
m = model.set_variable(var_type="_x", var_name="m", shape=(1, 1))

# Volumetric flow rates into tank (m^3/h)
F_in_1 = model.set_variable(var_type="_u", var_name="F_in_1", shape=(1, 1))
F_in_2 = model.set_variable(var_type="_u", var_name="F_in_2", shape=(1, 1))

# Time-varying parameter: Forecasted outflow rate (m^3/h)
F_out_fcast = model.set_variable(var_type="_tvp", var_name="F_out_fcast", shape=(1, 1))

# Augmented state: Outflow forecast error (m^3/h)
# This captures the difference between true F_out and the forecast
F_out_error = model.set_variable(var_type="_x", var_name="F_out_error", shape=(1, 1))

# Total outflow is the sum of forecast + error
F_out = F_out_fcast + F_out_error

# Augmented states: Concentration of mineral in feeds (tons/m^3)
# These are unmeasured input disturbances modeled as states
C_in_1 = model.set_variable(var_type="_x", var_name="C_in_1", shape=(1, 1))
C_in_2 = model.set_variable(var_type="_x", var_name="C_in_2", shape=(1, 1))

# Cross-sectional area (m^2)
A = 7.0

# Differential equations (ODE right-hand side)
dL_dt = (F_in_1 + F_in_2 - F_out) / A
dm_dt = F_in_1 * C_in_1 + F_in_2 * C_in_2 - F_out * m / (L * A)
model.set_rhs("L", dL_dt)
model.set_rhs("m", dm_dt)

# Augmented states: unmeasured disturbances to be estimated
model.set_rhs("F_out_error", cas.DM(0))  # outflow forecast error
model.set_rhs("C_in_1", cas.DM(0))       # feed concentration 1
model.set_rhs("C_in_2", cas.DM(0))       # feed concentration 2

# Outputs
C_out = m / (L * A)
model.set_expression("C_out", C_out)
model.set_expression("F_out", F_out)  # Store total F_out as auxiliary variable

# Measurements: L (level) and C_out (concentration)
model.set_meas("L_meas", L)
model.set_meas("C_out_meas", C_out)

model.setup()

# %%
# Variable descriptions
var_info = {
    "L": {"desc": "Tank level", "units": "$m$"},
    "L_meas": {"desc": "Measured tank level", "units": "$m$"},
    "m": {"desc": "Mass of mineral in tank", "units": "tons"},
    "F_in_1": {"desc": "Volumetric flow rate into tank (feed 1)", "units": "$m^3/h$"},
    "F_in_2": {"desc": "Volumetric flow rate into tank (feed 2)", "units": "$m^3/h$"},
    "F_out": {"desc": "Volumetric outflow rate from tank", "units": "$m^3/h$"},
    "F_out_fcast": {"desc": "Forecasted outflow rate", "units": "$m^3/h$"},
    "F_out_error": {"desc": "Outflow forecast error (actual - forecast)", "units": "$m^3/h$"},
    "C_in_1": {"desc": "Concentration of mineral in feed 1", "units": "$tons/m^3$"},
    "C_in_2": {"desc": "Concentration of mineral in feed 2", "units": "$tons/m^3$"},
    "C_out": {"desc": "Output concentration of mineral", "units": "$tons/m^3$"},
    "C_out_meas": {"desc": "Measured output concentration", "units": "$tons/m^3$"},
}

# %% [markdown]
# ## Construct MPC

# %%
mpc = do_mpc.controller.MPC(model)

mpc_params = {
    "n_horizon": 30,
    "t_step": 1.0,
    "n_robust": 1,
    "store_full_solution": True,
}
mpc.set_param(**mpc_params)

# Constraints
mpc.bounds["lower", "_x", "L"] = 0.1
mpc.bounds["upper", "_x", "L"] = 4.0
mpc.bounds["lower", "_u", "F_in_1"] = 0.0
mpc.bounds["upper", "_u", "F_in_1"] = 10.0
mpc.bounds["lower", "_u", "F_in_2"] = 0.0
mpc.bounds["upper", "_u", "F_in_2"] = 10.0

# Objective: keep output concentration at setpoint
# Reference states and expressions through mpc.model, not the original variables
C_out = mpc.model.aux["C_out"]
L = mpc.model.x["L"]
C_out_sp = 0.5
L_sp = 2.0
lterm = (C_out_sp - C_out) ** 2 + 0.05 * (L_sp - L) ** 2
mterm = cas.DM(0.0)  # Terminal cost (not used)
mpc.set_objective(mterm=mterm, lterm=lterm)

# MV weights
mpc.set_rterm(F_in_1=1.0, F_in_2=1.0)

# Configure MPC TVP function for F_out forecast
# This provides the rolling forecast over the prediction horizon
# MUST be set BEFORE mpc.setup()
tvp_template_mpc = mpc.get_tvp_template()

def tvp_fun_mpc(t_now):
    # This will be updated in the simulation loop with forecasted F_out values
    return tvp_template_mpc

mpc.set_tvp_fun(tvp_fun_mpc)

mpc.setup()

# %% [markdown]
# ## Create State Estimator

# %%
# Create estimator (EKF) to estimate F_out_error, C_in_1, and C_in_2
estimator = do_mpc.estimator.EKF(model)

estimator.settings.t_step = mpc.settings.t_step

# Process noise covariance (for state dynamics)
# States: [L, m, F_out_error, C_in_1, C_in_2]
# F_out_error, C_in_1, and C_in_2 are unmeasured disturbances with process noise (random walk)
P_v = np.diag([0.0, 0.0, 0.01, 0.01, 0.01])  # Process noise for F_out_error, C_in_1, C_in_2

# Measurement noise covariance (for measurements)
# We have 2 measurements: L_meas and C_out_meas
P_w = np.diag([0.01, 0.01])  # Measurement noise for L and C_out

estimator.P_v = P_v
estimator.P_w = P_w

# Initial state covariance
P_x = np.eye(5) * 0.1
estimator.P_x = P_x

# Configure estimator TVP function
# Estimator uses current forecast value only (no horizon)
# MUST be set BEFORE estimator.setup()
tvp_template_est = estimator.get_tvp_template()

def tvp_fun_est(t_now):
    # This will be updated in the simulation loop with current F_out forecast
    return tvp_template_est

estimator.set_tvp_fun(tvp_fun_est)

estimator.setup()

# %% [markdown]
# ## Create Simulator

# %%
# Create simulator
simulator = do_mpc.simulator.Simulator(model)

simulator.set_param(t_step=mpc.settings.t_step)

# TVP template for simulator (will be set in simulation loop)
tvp_template_sim = simulator.get_tvp_template()

def tvp_fun_sim(t_now):
    # This will be updated in the simulation loop with actual F_out_fcast values
    return tvp_template_sim

simulator.set_tvp_fun(tvp_fun_sim)

simulator.setup()

# %% [markdown]
# ## Run Simulation

# %%
# Set initial state
# States: [L, m, F_out_error, C_in_1, C_in_2]
x0 = np.array([[2.0], [7.0], [0.0], [0.25], [0.75]])  
# L=2.0 m, m=7.0 tons, F_out_error=0.0 (assuming perfect initial forecast), 
# C_in_1=0.25, C_in_2=0.75

# Set initial state for all components
mpc.x0 = x0
simulator.x0 = x0
estimator.x0 = x0

# Initialize MPC and estimator
mpc.set_initial_guess()
estimator.set_initial_guess()

# %%
# Simulation parameters
n_steps = 100
rng = np.random.default_rng(42)  # For reproducibility

# Time step (hours)
dt = mpc.settings.t_step
n_horizon = mpc.settings.n_horizon

# Generate time-varying input disturbances
t = np.arange(n_steps) * dt

# Model assumptions
C_in_1_nominal = 0.25
C_in_2_nominal = 0.75

# Static disturbances introduced at t = 50 hours
C_in_1_offset = 0.05  # Changes mean from 0.25 to 0.30
C_in_2_offset = 0.10  # Changes mean from 0.75 to 0.85

# Time when disturbance is introduced
t_disturbance = 50.0

# Noise standard deviations
C_in_1_std = 0.1
C_in_2_std = 0.1

# Concentration of feed 1
C_in_1 = np.full(n_steps, C_in_1_nominal)
C_in_1[t >= t_disturbance] += C_in_1_offset
C_in_1 += rng.normal(scale=C_in_1_std, size=C_in_1.shape)
C_in_1 = np.clip(C_in_1, 0.1, 1.0)

# Concentration of feed 2
C_in_2 = np.full(n_steps, C_in_2_nominal)
C_in_2[t >= t_disturbance] += C_in_2_offset
C_in_2 += rng.normal(scale=C_in_2_std, size=C_in_2.shape)
C_in_2 = np.clip(C_in_2, 0.1, 1.0)

F_out_nominal = 5.0

# Std dev. of outflow variations
F_out_std = 0.1

# True discharge flow rate
F_out_true = np.full(n_steps, F_out_nominal)
F_out_true += rng.normal(scale=F_out_std, size=F_out_true.shape)
F_out_true = np.clip(F_out_true, 2.0, 10.0)

# Forecasted discharge flow rate (perfect forecast for now)
# In practice, this would come from an external forecasting system
F_out_fcast = F_out_true.copy()  # Perfect forecast
# Optionally add forecast bias/error here:
# F_out_fcast = F_out_true + 0.5  # Biased forecast

# Generate measurement noise (standard deviations from diagonal of P_w)
V = np.sqrt(np.diag(P_w)).reshape(1, -1) * rng.normal(size=(n_steps, model.n_v))

# Store noisy measurements manually for plotting
L_meas_history = []
C_out_meas_history = []
time_history = []

# Run simulation
for k in range(n_steps):
    # Update TVP templates with forecast values
    
    # Simulator: uses current forecast value
    tvp_template_sim['F_out_fcast'] = F_out_fcast[k]
    
    # Estimator: uses current forecast value
    tvp_template_est['F_out_fcast'] = F_out_fcast[k]
    
    # MPC: uses forecast over prediction horizon
    for i in range(n_horizon + 1):
        # Get forecast value at k+i (use last value if beyond array)
        idx = min(k + i, n_steps - 1)
        tvp_template_mpc['_tvp', i, 'F_out_fcast'] = F_out_fcast[idx]
    
    # Get control input from MPC
    u0 = mpc.make_step(estimator.x0)    

    # Set disturbance states in the simulator from input sequences
    # F_out_error = F_out_true - F_out_fcast
    simulator.x0["F_out_error"] = F_out_true[k] - F_out_fcast[k]
    simulator.x0["C_in_1"] = C_in_1[k]
    simulator.x0["C_in_2"] = C_in_2[k]

    # Simulate the system (with true disturbances) and add measurement noise
    y_next = simulator.make_step(u0, v0=V[k].reshape(-1, 1))

    # Store noisy measurements for plotting
    # y_next is a (2,1) array: [L_meas, C_out_meas]
    L_meas_history.append(float(y_next[0]))
    C_out_meas_history.append(float(y_next[1]))
    time_history.append(simulator.data["_time"][-1])

    # Estimate states (including F_out_error, C_in_1, C_in_2) using EKF
    # Pass measurement, control input, process noise covariance, and measurement noise covariance
    x_est = estimator.make_step(y_next=y_next, u_next=u0, Q_k=P_v, R_k=P_w)

print(f"Simulation completed: {n_steps} steps")
print(f"Static disturbances introduced at t = {t_disturbance} hours")

# Convert to numpy arrays for easier plotting
L_meas_history = np.array(L_meas_history)
C_out_meas_history = np.array(C_out_meas_history)
time_history = np.array(time_history)
# Out:
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:     2045
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:      568
#
# Total number of variables............................:      680
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      176
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      605
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
# ...

# %% [markdown]
# ## Time Series Plots

# %%
# Create figure for states
fig, ax = plt.subplots(5, 1, figsize=(7, 9), sharex=True)

# Plot Level (L)
ax[0].plot(
    simulator.data["_time"],
    simulator.data["_x", "L"],
    label="L (simulator)",
    linewidth=2,
)
ax[0].plot(
    estimator.data["_time"],
    estimator.data["_x", "L"],
    "--",
    label="L (estimator)",
    linewidth=2,
)
ax[0].axhline(y=L_sp, color="r", linestyle=":", label="L setpoint")
ax[0].axvline(x=t_disturbance, color="k", linestyle="--", alpha=0.3, linewidth=1)
ax[0].set_ylabel("Level (m)")
ax[0].legend()
ax[0].grid(True)

# Plot mass (m)
ax[1].plot(
    simulator.data["_time"],
    simulator.data["_x", "m"],
    label="m (simulator)",
    linewidth=2,
)
ax[1].plot(
    estimator.data["_time"],
    estimator.data["_x", "m"],
    "--",
    label="m (estimator)",
    linewidth=2,
)
ax[1].axvline(x=t_disturbance, color="k", linestyle="--", alpha=0.3, linewidth=1)
ax[1].set_ylabel("Mass (tons)")
ax[1].legend()
ax[1].grid(True)

# Plot F_out (true vs estimated)
# F_out = F_out_fcast + F_out_error
ax[2].plot(
    simulator.data["_time"],
    simulator.data["_aux", "F_out"],
    label="F_out (true)",
    linewidth=2,
)
# Estimated F_out from estimator
F_out_est = estimator.data["_tvp", "F_out_fcast"] + estimator.data["_x", "F_out_error"]
ax[2].plot(
    estimator.data["_time"],
    F_out_est,
    "--",
    label="F_out (estimated)",
    linewidth=2,
)
# Forecast
ax[2].plot(
    simulator.data["_time"],
    simulator.data["_tvp", "F_out_fcast"],
    ":",
    label="F_out (forecast)",
    linewidth=2,
    alpha=0.7,
)
ax[2].axvline(x=t_disturbance, color="k", linestyle="--", alpha=0.3, linewidth=1)
ax[2].set_ylabel("Outflow (m³/h)")
ax[2].legend()
ax[2].grid(True)

# Plot C_in_1 (true vs estimated)
ax[3].plot(
    simulator.data["_time"],
    simulator.data["_x", "C_in_1"],
    label="C_in_1 (true)",
    linewidth=2,
)
ax[3].plot(
    estimator.data["_time"],
    estimator.data["_x", "C_in_1"],
    "--",
    label="C_in_1 (estimated)",
    linewidth=2,
)
ax[3].axhline(y=C_in_1_nominal, color="gray", linestyle=":", label="Nominal value", linewidth=1)
ax[3].axvline(x=t_disturbance, color="k", linestyle="--", alpha=0.3, linewidth=1, label="Disturbance")
ax[3].set_ylabel("C_in_1 (tons/m³)")
ax[3].legend()
ax[3].grid(True)

# Plot C_in_2 (true vs estimated)
ax[4].plot(
    simulator.data["_time"],
    simulator.data["_x", "C_in_2"],
    label="C_in_2 (true)",
    linewidth=2,
)
ax[4].plot(
    estimator.data["_time"],
    estimator.data["_x", "C_in_2"],
    "--",
    label="C_in_2 (estimated)",
    linewidth=2,
)
ax[4].axhline(y=C_in_2_nominal, color="gray", linestyle=":", label="Nominal value", linewidth=1)
ax[4].axvline(x=t_disturbance, color="k", linestyle="--", alpha=0.3, linewidth=1, label="Disturbance")
ax[4].set_ylabel("C_in_2 (tons/m³)")
ax[4].set_xlabel("Time (h)")
ax[4].legend()
ax[4].grid(True)

plt.tight_layout()
plt.show()

# %%
# Plot F_out forecast error
fig, ax = plt.subplots(1, 1, figsize=(7, 3))

# Plot F_out_error (true vs estimated)
ax.plot(
    simulator.data["_time"],
    simulator.data["_x", "F_out_error"],
    label="F_out_error (true)",
    linewidth=2,
)
ax.plot(
    estimator.data["_time"],
    estimator.data["_x", "F_out_error"],
    "--",
    label="F_out_error (estimated)",
    linewidth=2,
)
ax.axhline(y=0, color="gray", linestyle=":", linewidth=1)
ax.axvline(x=t_disturbance, color="k", linestyle="--", alpha=0.3, linewidth=1)
ax.set_ylabel("F_out Forecast Error (m³/h)")
ax.set_xlabel("Time (h)")
ax.set_title("Outflow Forecast Error (Actual - Forecast)")
ax.legend()
ax.grid(True)

plt.tight_layout()
plt.show()

# %%
# Create figure for inputs

var_names = ["F_in_1", "F_in_2"]
n = len(var_names)
fig, axes = plt.subplots(n, 1, figsize=(7, 1 + 1.5*n), sharex=True)

for ax, name in zip(axes, var_names):
    ax.step(
        mpc.data["_time"],
        mpc.data["_u", name],
        where="post",
        label=name,
        linewidth=2,
    )
    units = var_info[name]["units"]
    ax.set_ylabel(f"{name} ({units})")
    ax.legend()
    ax.set_title(var_info[name]["desc"])
    ax.grid(True)

plt.tight_layout()
plt.show()

# %%
# Create figure for output concentration and level
fig, ax = plt.subplots(2, 1, figsize=(7, 5), sharex=True)

# Plot 1: Tank Level
ax[0].plot(
    simulator.data["_time"],
    simulator.data["_x", "L"],
    label="L (true)",
    linewidth=2,
)

# Plot noisy level measurements as scatter points
ax[0].scatter(
    time_history,
    L_meas_history,
    label="L (measurements)",
    marker="o",
    s=20,
    alpha=0.6,
    color="orange",
    zorder=3,
)

# Plot estimated level
ax[0].plot(
    estimator.data["_time"],
    estimator.data["_x", "L"],
    "--",
    label="L (estimated)",
    linewidth=2,
)

# Plot level setpoint
ax[0].axhline(
    y=L_sp, color="r", linestyle=":", label="L setpoint", linewidth=2
)

ax[0].set_ylabel("Level (m)")
ax[0].legend()
ax[0].grid(True)
ax[0].set_title("Tank Level")

# Plot 2: Output Concentration
# Calculate C_out from estimated states (since EKF doesn't store aux expressions)
# C_out = m / (L * A)
C_out_estimated = estimator.data["_x", "m"] / (estimator.data["_x", "L"] * A)

# Plot true C_out from simulator
ax[1].plot(
    simulator.data["_time"],
    simulator.data["_aux", "C_out"],
    label="C_out (true)",
    linewidth=2,
)

# Plot noisy measurements as scatter points (manually stored)
ax[1].scatter(
    time_history,
    C_out_meas_history,
    label="C_out (measurements)",
    marker="o",
    s=20,
    alpha=0.6,
    color="orange",
    zorder=3,
)

# Plot estimated C_out
ax[1].plot(
    estimator.data["_time"],
    C_out_estimated,
    "--",
    label="C_out (estimated)",
    linewidth=2,
)

# Plot setpoint
ax[1].axhline(
    y=C_out_sp, color="r", linestyle=":", label="C_out setpoint", linewidth=2
)

ax[1].set_ylabel("Concentration (tons/m³)")
ax[1].set_xlabel("Time (h)")
ax[1].legend()
ax[1].grid(True)
ax[1].set_title("Output Concentration")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Check out Do-MPC's Default Plots

# %%
from do_mpc.graphics import Graphics, default_plot

# Create graphics object
graphics = Graphics(simulator.data)

# %%
# Use do-mpc's default_plot for standard visualization
fig, ax, graphics = default_plot(mpc.data, figsize=(7, 10))
plt.tight_layout()
plt.show()

# %%
# Plot simulator data
fig, ax, graphics = default_plot(simulator.data, figsize=(7, 10))
plt.tight_layout()
plt.show()

# %%
# Plot estimator data
fig, ax, graphics = default_plot(estimator.data, aux_list=[], figsize=(7, 8.5))
plt.tight_layout()
plt.show()
